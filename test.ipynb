# %%
True.__index__()
# Out:
# 1

# %%
import torch

torch.zeros(3, 4, 5, 6)[0, torch.tensor([[0, 2], [1, 0]], dtype=torch.long)].shape
# Out:
# torch.Size([2, 2, 5, 6])

# %%
import numpy as np

np.zeros((3, 4, 5))[0, np.array([[0, 2], [1, 0]], dtype=np.long)].shape
# Out:
# (2, 2, 5)

# %%
torch.zeros(3, 4, 5, 6)[0, True].shape
# Out:
# torch.Size([1, 4, 5, 6])

# %%
np.zeros((3, 4, 5, 6))[0, True].shape
# Out:
# (1, 4, 5, 6)

# %%
import numpy as np

np.array(True).__index__()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 import numpy as np
#       2
# ----> 3 np.array(True).__index__()
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
slice(None) == slice(None, None, None)
# Out:
# True

# %%
bool(np.array(False))
# Out:
# False

# %%
import jax.numpy as jnp
import numpy as np

jnp.array(True).dtype == bool
# Out:
# True

# %%
isinstance(jnp.array(False), np.ndarray)
# Out:
# False

# %%
np.zeros((3, 4, 5))[..., True].shape
# Out:
# (3, 4, 5, 1)
